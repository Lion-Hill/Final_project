# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import urllib.request
from time import sleep
from bs4 import BeautifulSoup

# %%
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')

dr = webdriver.Chrome(r'/Users/pgho8/Likelion_AI6/Final_project/chromedriver', chrome_options=options)
# Out:
# <ipython-input-6-32cff05fa32a>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   dr = webdriver.Chrome(r'/Users/pgho8/Likelion_AI6/Final_project/chromedriver', chrome_options=options)
# <ipython-input-6-32cff05fa32a>:5: DeprecationWarning: use options instead of chrome_options
#   dr = webdriver.Chrome(r'/Users/pgho8/Likelion_AI6/Final_project/chromedriver', chrome_options=options)

# %%
def pageUrl(category, pageNum):
    
    url = f'https://www.musinsa.com/category/{category}?d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page={pageNum}&display_cnt=90&sale_goods=&group_sale=&kids=N&ex_soldout=&color=&price1=&price2=&exclusive_yn=&shoeSizeOption=&tags=&campaign_id=&timesale_yn=&q=&includeKeywords=&measure='
    return url

# %%
category = {'상의' : '001',
           }

# %%
# url = pageUrl(category['긴소매티셔츠'], 1)
# dr.get(url)

# %%
# totalPageNum = dr.find_element(By.CSS_SELECTOR,'.totalPagingNum').text
    
for i in range(3):
    url = pageUrl(category['상의'], i+1)
    dr.get(url)
    sleep(1)
    html = dr.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    imgs = soup.select('#searchList > li > div.li_inner > div.list_img > a > img')
    #searchList > li:nth-child(1) > div.li_inner > div.list_img > a:nth-child(1) > img
    print(imgs)

#     imgs = soup.select('#searchList > li')
#     # urls = soup.select('div.li_inner a')

#     for img in imgs:
#         srcset = img.get('src')
#         if srcset[-3] == 'p' or srcset[-3] == 'g' or ('_brand' in srcset):
#             continue
#         if len(srcset):
#             src = str(srcset)
#             filename = src.split('/')[-1]
#             print(src, i+1)
# Out:
# [<img alt="커버낫(COVERNAT) 에센셜 쿨 코튼 2-PACK 티셔츠" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210316/1848166/1848166_11_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>, <img alt="라퍼지스토어(LAFUDGESTORE) 시티보이 빅오버 옥스포드 반팔 셔츠_Sky Blue" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210503/1935180/1935180_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>, <img alt="수아레(SUARE) 린넨 라이크 카라 하프 니트 - 8 COLOR" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210517/1954316/1954316_4_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>, <img alt="랩12(LAB12) 22S/S 오버핏 피케티셔츠 (블랙)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20190430/1031260/1031260_5_125.jpg" src="//image.msscdn.net/images/no_image_125.png"/>, <img alt="무신사 스탠다드(MUSINSA STANDARD) 베이식 긴팔 티셔츠 [화이트]" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_i
# ...
